# %%
import numpy as np
import matplotlib.pyplot as plt
import json
import math

# %%
plt.rc('font', size=15)          # controls default text sizes
plt.rc('legend', fontsize=12)

# %%
dataset = "superconduct"

# %%
with open(f"../random_forest_builder/scores_{dataset}.json", "r") as f:
    data = json.loads(f.read())
    print(data)
x, y = [], []
for depth, [k, r2] in data.items():
    x.append(depth)
    y.append(r2)
fig, ax = plt.subplots()
ax.set_ylabel("R2 score")
ax.set_xlabel("depth")
ax.plot(x, y, "o")
ax.xaxis.grid()
ax.yaxis.grid()
ax.set_title(f"R2 score vs. depth - {dataset}")
plt.savefig(f"plots/{dataset}_R2", dpi=300, bbox_inches='tight')
plt.show()
# Out:
# {'1': [2, 0.5439574807143206], '2': [6, 0.6385768806974637], '3': [50, 0.6858133329098313], '4': [410, 0.7298399124400013], '5': [2544, 0.762448930123022], '6': [14646, 0.8063220655793365], '7': [71576, 0.8386556918665814], '8': [308622, 0.8621423604542439], '9': [1183427, 0.8819397940889941], '10': [4083523, 0.8956290935737592], '11': [12784812, 0.9043843550837264], '12': [35198139, 0.9108665057368501]}

# %%
n=40
no_trees=20

# %%
# Proximal method
result_cs = {}
for depth in range(2,5):
    result_cs[depth] = []
    for C in np.linspace(0.1, 1.4, 10):
        for lmda_i, lmda in enumerate(10 ** np.linspace(-5,2,8)):
            try:
                f =open(f"../results/cs/{dataset}_n={n}_no_trees={no_trees}_depth={depth}_C={C:.3}_lambda={lmda:.6}.json")
                data = json.loads(f.read())
                # print(data)
                result_cs[depth].append((data["measurements"], data["mse"]/data['true_fourier_norm_squared'], data["C"], data["lambda"], data["optimization_time"]))
            except:
                print(f"Couldn't find results/{dataset}_n={n}_no_trees={no_trees}_depth={depth}_C={C:.3}_lambda={lmda:.6}.json")

# %%
from matplotlib.ticker import MaxNLocator
fig, ax = plt.subplots()
ax.set_ylabel("runtime (seconds)")
ax.set_xlabel("depth")
y1, y2, y3, y4 = [], [], [], []
x = [2,3,4]
for depth in range(2,5):
    print("depth", depth)
    for m, normalized_mse, C, lmbda, time in result_cs[depth]:
        if C==1.4 and lmbda ==0.001:
            y1.append(time)
            y1_mse = normalized_mse
        if C==0.8222222222222221 and lmbda ==0.001:
            y2.append(time)
            y2_mse = normalized_mse
        if C==1.4 and lmbda ==0.01:
            y3.append(time)
            y3_mse = normalized_mse
        if C==0.8222222222222221 and lmbda ==0.01:
            y4.append(time)
            y4_mse = normalized_mse




ax.plot(x, y1,'o', markersize=8, label=f"mse={100*y1_mse:.8f}")
ax.plot(x, y2,'*', markersize=8, label=f"mse={100*y2_mse:.8f}")
ax.plot(x, y3,'.', markersize=8, label=f"mse={100*y3_mse:.8f}")
ax.plot(x, y4,'x', markersize=8, label=f"mse={100*y4_mse:.8f}")
ax.set_yscale("log")
ax.xaxis.grid()
ax.yaxis.grid()
ax.xaxis.set_major_locator(MaxNLocator(integer=True))
ax.legend()
ax.set_title(f"Runtime vs depth of CS - n=40")
plt.savefig(f"plots/{dataset}_cs_runtimes", dpi=300, bbox_inches='tight')
plt.show()
# Out:
# depth 2
# depth 3
# depth 4

# %%
n=324
no_trees=20

# %%
# Reed-solomon method examination
result_reed_solomon = {}
for depth in [2,3,4,5,6]:
    print("depth=", depth)
    result_reed_solomon[depth] = []
    for C in [0.05, 0.1 , 0.15, 0.2 , 0.4, 0.6, 0.8]:
        for ratio in [1.1, 2.6, 5.0]:
            try:
                f =open(f"../results/reed_solomon/{dataset}_n={n}_no_trees={no_trees}_depth={depth}_C={C:.3}_ratio={ratio:.3}.json")
                data = json.loads(f.read())
                # print(data)
                normalized_mse = data["mse"]/data['true_fourier_norm_squared']
                print(data["C"], data["ratio"], normalized_mse, data["measurements"])
                result_reed_solomon[depth].append((data["measurements"], data["mse"]/data['true_fourier_norm_squared'],  data["C"], data["ratio"],  data["time_cached"]))
            except:
                print(f"Could not find {dataset}_n={n}_no_trees={no_trees}_depth={depth}_C={C:.3}_ratio={ratio:.3}.json")
# Out:
# depth= 2
# Could not find superconduct_n=324_no_trees=20_depth=2_C=0.05_ratio=1.1.json
# Could not find superconduct_n=324_no_trees=20_depth=2_C=0.05_ratio=2.6.json
# Could not find superconduct_n=324_no_trees=20_depth=2_C=0.05_ratio=5.0.json
# Could not find superconduct_n=324_no_trees=20_depth=2_C=0.1_ratio=1.1.json
# Could not find superconduct_n=324_no_trees=20_depth=2_C=0.1_ratio=2.6.json
# Could not find superconduct_n=324_no_trees=20_depth=2_C=0.1_ratio=5.0.json
# Could not find superconduct_n=324_no_trees=20_depth=2_C=0.15_ratio=1.1.json
# Could not find superconduct_n=324_no_trees=20_depth=2_C=0.15_ratio=2.6.json
# Could not find superconduct_n=324_no_trees=20_depth=2_C=0.15_ratio=5.0.json
# 0.2 1.1 1.0 0
# 0.2 2.6 1.0 0
# 0.2 5.0 1.0 0
# Could not find superconduct_n=324_no_trees=20_depth=2_C=0.4_ratio=1.1.json
# 0.4 2.6 1.0 0
# 0.4 5.0 1.0 0
# 0.6 1.1 0.016071458512447352 348
# 0.6 2.6 1.0 0
# 0.6 5.0 1.0 0
# 0.8 1.1 0.016071458512447352 348
# 0.8 2.6 1.0 0
# 0.8 5.0 1.0 0
# depth= 3
# Could not find superconduct_n=324_no_trees=20_depth=3_C=0.05_ratio=1.1.json
# 0.05 2.6 1.0 0
# 0.05 5.0 1.0 0
# 0.1 1.1 0.08796070707994903 1128
# 0.1 2.6 1.0 0
# 0.1 5.0 1.0 0
# 0.15 1.1 0.08796070707994903 1128
# 0.15 2.6 0.10400016969024971 376
# 0.15 5.0 1.0 0
# 0.2 1.1 0.006606467391722095 2256
# 0.2 2.6 0.023692032537196657 752
# 0.2 5.0 1.0 0
# 0.4 1.1 4.417704766243844e-05 4512
# 0.4 2.6 0.004281629075143128 1880
# 0.4 5.0 1.0 0
# 0.6 1.1 4.417704766243844e-05 4512
# 0.6 2.6 0.0034572503587470185 2256
# 0.6 5.0 0.006682475395974945 1504
# 0.8 1.1 6.790737597246698e-32 9024
# 0.8 2.6 0.0001937147363561745 3760
# 0.8 5.0 0.003200052834246764 3008
# depth= 4
# 0.05 1.1 0.03498509463440521 6240
# 0.05 2.6 0.03632771601246781 2600
# 0.05 5.0 0.9999999999999992 0
# 0.1 1.1 0.01418677532048383 12480
# 0.1 2.6 0.03388498457675082 5200
# 0.1 5.0 0.04249799618407694 4160
# 0.15 1.1 0.01418677532048383 12480
# 0.15 2.6 0.034347022855248814 7280
# 0.15 5.0 0.04249799618407694 4160
# 0.2 1.1 0.0030063347531979704 24960
# 0.2 2.6 0.016044024263654668 11440
# 0.2 5.0 0.016616948065082966 8320
# 0.4 1.1 0.00018081285854965105 49920
# 0.4 2.6 0.004329267252179597 22880
# 0.4 5.0 0.004374575442363251 20800
# 0.6 1.1 0.00018081285854965105 49920
# 0.6 2.6 0.0012013870666358025 29120
# 0.6 5.0 0.004374575442363251 20800
# 0.8 1.1 6.119802941417069e-06 99840
# 0.8 2.6 0.0005372331285993366 45760
# 0.8 5.0 0.0009388837002557842 41600
# depth= 5
# 0.05 1.1 0.031243301167556133 31872
# 0.05 2.6 0.04508363145447829 18592
# 0.05 5.0 0.046730189332994644 13280
# 0.1 1.1 0.014372104490127026 63744
# 0.1 2.6 0.0227503744574446 37184
# 0.1 5.0 0.024353611132621203 26560
# 0.15 1.1 0.005147773890184074 127488
# 0.15 2.6 0.010984461368199465 69056
# 0.15 5.0 0.014201008601237141 53120
# 0.2 1.1 0.005147773890184074 127488
# 0.2 2.6 0.01063917637176456 74368
# 0.2 5.0 0.014201008601237141 53120
# 0.4 1.1 0.0023197871634362483 254976
# 0.4 2.6 0.0038253732894233746 148736
# 0.4 5.0 0.005654960498041757 111552
# 0.6 1.1 0.00010060301550369234 509952
# 0.6 2.6 0.0009926043865985488 276224
# 0.6 5.0 0.0017717346091869997 217792
# 0.8 1.1 0.00010060301550369234 509952
# 0.8 2.6 0.0006212833615952068 297472
# 0.8 5.0 0.0017418431039096225 223104
# depth= 6
# 0.05 1.1 0.020802480111441063 310272
# 0.05 2.6 0.02607295717893459 168064
# 0.05 5.0 0.026448230050425 132512
# 0.1 1.1 0.009020367888319327 620544
# 0.1 2.6 0.01572994117353575 336128
# 0.1 5.0 0.017087313239440686 265024
# 0.15 1.1 0.006028967248043825 827392
# 0.15 2.6 0.009797247067012732 568832
# 0.15 5.0 0.011514848615540188 478336
# 0.2 1.1 0.0028906144667933814 1241088
# 0.2 2.6 0.007484646312967115 672256
# 0.2 5.0 0.009905820937066783 530048
# 0.4 1.1 0.0003728580107347228 2482176
# 0.4 2.6 0.00222905522340414 1344512
# 0.4 5.0 0.003658014847213234 1060096
# 0.6000000000000001 1.1 0.00010583757358053085 3309568
# 0.6000000000000001 2.6 0.0006853945531663303 2275328
# 0.6 5.0 0.0016361425755578184 1913344
# 0.8 1.1 1.8665539305142036e-05 4964352
# 0.8 2.6 0.0003127994574548816 2689024
# 0.8 5.0 0.0010103348544003247 2120192

# %%
# Reed solomon one more time after examination
C_ratio_list = {2:[(0.6,1.1)], 3:[(0.1,1.1)], 4:[(0.05, 2.6)], 5:[(0.05, 5.0)]}
result_reed_solomon = {}
for depth in [2, 3, 4, 5, 6]:
    print(depth)
    result_reed_solomon[depth] = []
    for C in [0.05, 0.1, 0.15, 0.2, 0.4, 0.6, 0.8]:
        for ratio in [1.1, 2.6, 5.0]:
            try:
                f =open(f"../results/reed_solomon/{dataset}_n={n}_no_trees={no_trees}_depth={depth}_C={C:.3}_ratio={ratio:.3}.json")
                data = json.loads(f.read())
                normalized_mse = data["mse"]/data['true_fourier_norm_squared']
                print(normalized_mse)
                # print(data["C"], data["ratio"], data["mse"], normalized_mse, data["measurements"])
                if normalized_mse<0.3:
                    result_reed_solomon[depth].append((data["measurements"], normalized_mse*100,  data["C"], data["ratio"],  data["time_cached"]))
            except:
                print(f"Could not find {dataset}_n={n}_no_trees={no_trees}_depth={depth}_C={C:.3}_ratio={ratio:.3}.json")
# Out:
# 2
# Could not find superconduct_n=324_no_trees=20_depth=2_C=0.05_ratio=1.1.json
# Could not find superconduct_n=324_no_trees=20_depth=2_C=0.05_ratio=2.6.json
# Could not find superconduct_n=324_no_trees=20_depth=2_C=0.05_ratio=5.0.json
# Could not find superconduct_n=324_no_trees=20_depth=2_C=0.1_ratio=1.1.json
# Could not find superconduct_n=324_no_trees=20_depth=2_C=0.1_ratio=2.6.json
# Could not find superconduct_n=324_no_trees=20_depth=2_C=0.1_ratio=5.0.json
# Could not find superconduct_n=324_no_trees=20_depth=2_C=0.15_ratio=1.1.json
# Could not find superconduct_n=324_no_trees=20_depth=2_C=0.15_ratio=2.6.json
# Could not find superconduct_n=324_no_trees=20_depth=2_C=0.15_ratio=5.0.json
# 1.0
# 1.0
# 1.0
# Could not find superconduct_n=324_no_trees=20_depth=2_C=0.4_ratio=1.1.json
# 1.0
# 1.0
# 0.016071458512447352
# 1.0
# 1.0
# 0.016071458512447352
# 1.0
# 1.0
# 3
# Could not find superconduct_n=324_no_trees=20_depth=3_C=0.05_ratio=1.1.json
# 1.0
# 1.0
# 0.08796070707994903
# 1.0
# 1.0
# 0.08796070707994903
# 0.10400016969024971
# 1.0
# 0.006606467391722095
# 0.023692032537196657
# 1.0
# 4.417704766243844e-05
# 0.004281629075143128
# 1.0
# 4.417704766243844e-05
# 0.0034572503587470185
# 0.006682475395974945
# 6.790737597246698e-32
# 0.0001937147363561745
# 0.003200052834246764
# 4
# 0.03498509463440521
# 0.03632771601246781
# 0.9999999999999992
# 0.01418677532048383
# 0.03388498457675082
# 0.04249799618407694
# 0.01418677532048383
# 0.034347022855248814
# 0.04249799618407694
# 0.0030063347531979704
# 0.016044024263654668
# 0.016616948065082966
# 0.00018081285854965105
# 0.004329267252179597
# 0.004374575442363251
# 0.00018081285854965105
# 0.0012013870666358025
# 0.004374575442363251
# 6.119802941417069e-06
# 0.0005372331285993366
# 0.0009388837002557842
# 5
# 0.031243301167556133
# 0.04508363145447829
# 0.046730189332994644
# 0.014372104490127026
# 0.0227503744574446
# 0.024353611132621203
# 0.005147773890184074
# 0.010984461368199465
# 0.014201008601237141
# 0.005147773890184074
# 0.01063917637176456
# 0.014201008601237141
# 0.0023197871634362483
# 0.0038253732894233746
# 0.005654960498041757
# 0.00010060301550369234
# 0.0009926043865985488
# 0.0017717346091869997
# 0.00010060301550369234
# 0.0006212833615952068
# 0.0017418431039096225
# 6
# 0.020802480111441063
# 0.02607295717893459
# 0.026448230050425
# 0.009020367888319327
# 0.01572994117353575
# 0.017087313239440686
# 0.006028967248043825
# 0.009797247067012732
# 0.011514848615540188
# 0.0028906144667933814
# 0.007484646312967115
# 0.009905820937066783
# 0.0003728580107347228
# 0.00222905522340414
# 0.003658014847213234
# 0.00010583757358053085
# 0.0006853945531663303
# 0.0016361425755578184
# 1.8665539305142036e-05
# 0.0003127994574548816
# 0.0010103348544003247

# %%
# Binning method
from math import ceil
result_binning = {}

for depth in [2, 3, 4, 5, 6]:
    found = 0
    not_found = 0
    print("depth=", depth)
    result_binning[depth] = []
    for C in [0.05, 0.1 , 0.15, 0.2 , 0.4, 0.6, 0.8]:
        for ratio in [1.1, 2.6, 5.0]:
            # Iterations over the frequency recovery primitive
            cs_bins_range = np.linspace(0.2 * depth ** 2 , depth ** 2, 10)
            cs_bins_range = [ceil(a) for a in cs_bins_range]
            for cs_bins in cs_bins_range:
                for cs_iterations in [1, 2, 3]:
                    for cs_ratio in [1.1, 1.3, 1.5, 1.9, 2.1, 3.0]:
                        try:
                            f =open(f"../results/binning/{dataset}_n={n}_no_trees={no_trees}_depth={depth}_"
                                    f"C={C:.3}_ratio={ratio:.3}_csbins={cs_bins}_csiterations={cs_iterations}_"
                                    f"csratio={cs_ratio}.json")
                            found+=1 
                            data = json.loads(f.read())
                            #print(data)
                            normalized_mse = data["mse"]/data['true_fourier_norm_squared']
                            if normalized_mse<0.3:
                                result_binning[depth].append((data["measurements"], normalized_mse*100))
                        except:
                            not_found+=1
                            #print(f"Could not find {dataset}_n={n}_no_trees={no_trees}_depth={depth}_"
                            #        f"C={C:.3}_ratio={ratio:.3}_csbins={cs_bins}_csiterations={cs_iterations}_"
                            #        f"csratio={cs_ratio}.json")
    print(f"found {found}, not found {not_found}")
# Out:
# depth= 2
# found 1878, not found 1905
# depth= 3
# found 3327, not found 453
# depth= 4
# found 3660, not found 120
# depth= 5
# found 3717, not found 63
# depth= 6
# found 3759, not found 21

# %%
for depth in [2, 3, 4, 5, 6]:
    fig, ax = plt.subplots()
    ax.set_ylabel("mse", color="blue")
    ax.set_xlabel("number of measurements")
    ax.plot([a[0] for a in result_binning[depth]],[a[1] for a in result_binning[depth]],'.')
    ax.plot([a[0] for a in result_reed_solomon[depth]],[a[1] for a in result_reed_solomon[depth]],'*', markersize=15)
    ax.xaxis.grid()
    ax.yaxis.grid()
    ax.set_title(f"degree={depth}")
    # plt.savefig(f"plots/reed_solomon/superconduct-n={n}_d={depth}", dpi=300)
    plt.show()

# %%
# Random measurement method
from math import ceil
result_random = {}
for depth in [2,3,4,5]:
    result_random[depth] = []
    for C in [0.05, 0.1 , 0.15, 0.2 , 0.4, 0.6, 0.8]:
        for ratio in [1.1, 2.6, 5.0]:
            for sampling_factor in np.linspace(0.2,1.4,10):
                try:
                    dir_string= f"../results/random_parallel/{dataset}_n={n}_no_trees={no_trees}_depth={depth}_C={C:.3}_ratio={ratio:.3}_samplefactor={sampling_factor:.3}_ncores=10.json"
                    f =open(dir_string)
                    data = json.loads(f.read())
                    print(data)
                    normalized_mse = data["mse"]/data['true_fourier_norm_squared']
                    if normalized_mse < 0.3:
                        result_random[depth].append((data["measurements"], normalized_mse*100))
                except:
                    pass
                    # print(f" Couldn't find {dir_string}")
# Out:
# {'n': 324, 'no_trees': 20, 'depth': 2, 'C': 0.2, 'ratio': 1.1, 'sampling_factor': 0.2, 'n_cores': 10, 'wait_time': 100, 'k': 6, 'time_uncached': 3.552436828613281e-05, 'time_cached': 1.0013580322265625e-05, 'equality': False, 'mse': 1398.8587243216887, 'true_fourier_norm_squared': 1398.8587243216887, 'computed_fourier_norm_squared': 0, 'measurements': 0}
# {'n': 324, 'no_trees': 20, 'depth': 2, 'C': 0.2, 'ratio': 1.1, 'sampling_factor': 0.33333333333333337, 'n_cores': 10, 'wait_time': 100, 'k': 6, 'time_uncached': 4.6253204345703125e-05, 'time_cached': 1.0967254638671875e-05, 'equality': False, 'mse': 1398.8587243216887, 'true_fourier_norm_squared': 1398.8587243216887, 'computed_fourier_norm_squared': 0, 'measurements': 0}
# {'n': 324, 'no_trees': 20, 'depth': 2, 'C': 0.2, 'ratio': 1.1, 'sampling_factor': 0.4666666666666667, 'n_cores': 10, 'wait_time': 100, 'k': 6, 'time_uncached': 4.8160552978515625e-05, 'time_cached': 1.0013580322265625e-05, 'equality': False, 'mse': 1398.8587243216887, 'true_fourier_norm_squared': 1398.8587243216887, 'computed_fourier_norm_squared': 0, 'measurements': 0}
# {'n': 324, 'no_trees': 20, 'depth': 2, 'C': 0.2, 'ratio': 1.1, 'sampling_factor': 0.6000000000000001, 'n_cores': 10, 'wait_time': 100, 'k': 6, 'time_uncached': 4.506111145019531e-05, 'time_cached': 1.049041748046875e-05, 'equality': False, 'mse': 1398.8587243216887, 'true_fourier_norm_squared': 1398.8587243216887, 'computed_fourier_norm_squared': 0, 'measurements': 0}
# {'n': 324, 'no_trees': 20, 'depth': 2, 'C': 0.2, 'ratio': 1.1, 'sampling_factor': 0.7333333333333334, 'n_cores': 10, 'wait_time': 100, 'k': 6, 'time_uncached': 3.0517578125e-05, 'time_cached': 9.059906005859375e-06, 'equality': False, 'mse': 1398.8587243216887, 'true_fourier_norm_squared': 1398.8587243216887, 'computed_fourier_norm_squared': 0, 'measurements': 0}
# {'n': 324, 'no_trees': 20, 'depth': 2, 'C': 0.2, 'ratio': 1.1, 'sampling_factor': 0.8666666666666667, 'n_cores': 10, 'wait_time': 100, 'k': 6, 'time_uncached': 3.886222839355469e-05, 'time_cached': 7.867813110351562e-06, 'equality': False, 'mse': 1398.8587243216887, 'true_fourier_norm_squared': 1398.8587243216887, 'computed_fourier_norm_squared': 0, 'measurements': 0}
# {'n': 324, 'no_trees': 20, 'depth': 2, 'C': 0.2, 'ratio': 1.1, 'sampling_factor': 1.0, 'n_cores': 10, 'wait_time': 100, 'k': 6, 'time_uncached': 3.314018249511719e-05, 'time_cached': 8.821487426757812e-06, 'equality': False, 'mse': 1398.8587243216887, 'true_fourier_norm_squared': 1398.8587243216887, 'computed_fourier_norm_squared': 0, 'measurements': 0}
# {'n': 324, 'no_trees': 20, 'depth': 2, 'C': 0.2, 'ratio': 1.1, 'sampling_factor': 1.1333333333333333, 'n_cores': 10, 'wait_time': 100, 'k': 6, 'time_uncached': 3.814697265625e-05, 'time_cached': 8.58306884765625e-06, 'equality': False, 'mse': 1398.8587243216887, 'true_fourier_norm_squared': 1398.8587243216887, 'computed_fourier_norm_squared': 0, 'measurements': 0}
# {'n': 324, 'no_trees': 20, 'depth': 2, 'C': 0.2, 'ratio': 1.1, 'sampling_factor': 1.2666666666666666, 'n_cores': 10, 'wait_time': 100, 'k': 6, 'time_uncached': 3.24249267578125e-05, 'time_cached': 8.106231689453125e-06, 'equality': False, 'mse': 1398.8587243216887, 'true_fourier_norm_squared': 1398.8587243216887, 'computed_fourier_norm_squared': 0, 'measurements': 0}
# {'n': 324, 'no_trees': 20, 'depth': 2, 'C': 0.2, 'ratio': 1.1, 'sampling_factor': 1.4, 'n_cores': 10, 'wait_time': 100, 'k': 6, 'time_uncached': 2.956390380859375e-05, 'time_cached': 8.106231689453125e-06, 'equality': False, 'mse': 1398.8587243216887, 'true_fourier_norm_squared': 1398.8587243216887, 'computed_fourier_norm_squared': 0, 'measurements': 0}
# {'n': 324, 'no_trees': 20, 'depth': 2, 'C': 0.2, 'ratio': 2.6, 'sampling_factor': 0.2, 'n_cores': 10, 'wait_time': 100, 'k': 6, 'time_uncached': 3.4332275390625e-05, 'time_cached': 8.344650268554688e-06, 'equality': False, 'mse': 1398.8587243216887, 'true_fourier_norm_squared': 1398.8587243216887, 'computed_fourier_norm_squared': 0, 'measurements': 0}
# {'n': 324, 'no_trees': 20, 'depth': 2, 'C': 0.2, 'ratio': 2.6, 'sampling_factor': 0.33333333333333337, 'n_cores': 10, 'wait_time': 100, 'k': 6, 'time_uncached': 3.075599670410156e-05, 'time_cached': 8.58306884765625e-06, 'equality': False, 'mse': 1398.8587243216887, 'true_fourier_norm_squared': 1398.8587243216887, 'computed_fourier_norm_squared': 0, 'measurements': 0}
# {'n': 324, 'no_trees': 20, 'depth': 2, 'C': 0.2, 'ratio': 2.6, 'sampling_factor': 0.4666666666666667, 'n_cores': 10, 'wait_time': 100, 'k': 6, 'time_uncached': 3.0517578125e-05, 'time_cached': 8.821487426757812e-06, 'equality': False, 'mse': 1398.8587243216887, 'true_fourier_norm_squared': 1398.8587243216887, 'computed_fourier_norm_squared': 0, 'measurements': 0}
# {'n': 324, 'no_trees': 20, 'depth': 2, 'C': 0.2, 'ratio': 2.6, 'sampling_factor': 0.6000000000000001, 'n_cores': 10, 'wait_time': 100, 'k': 6, 'time_uncached': 4.5299530029296875e-05, 'time_cached': 9.775161743164062e-06, 'equality': False, 'mse': 1398.8587243216887, 'true_fourier_norm_squared': 1398.8587243216887, 'computed_fourier_norm_squared': 0, 'measurements': 0}
# {'n': 324, 'no_trees': 20, 'depth': 2, 'C': 0.2, 'ratio': 2.6, 'sampling_factor': 0.7333333333333334, 'n_cores': 10, 'wait_time': 100, 'k': 6, 'time_uncached': 4.482269287109375e-05, 'time_cached': 1.0013580322265625e-05, 'equality': False, 'mse': 1398.8587243216887, 'true_fourier_norm_squared': 1398.8587243216887, 'computed_fourier_norm_squared': 0, 'measurements': 0}
# {'n': 324, 'no_trees': 20, 'depth': 2, 'C': 0.2, 'ratio': 2.6, 'sampling_factor': 0.8666666666666667, 'n_cores': 10, 'wait_time': 100, 'k': 6, 'time_uncached': 4.38690185546875e-05, 'time_cached': 9.5367431640625e-06, 'equality': False, 'mse': 1398.8587243216887, 'true_fourier_norm_squared': 1398.8587243216887, 'computed_fourier_norm_squared': 0, 'measurements': 0}
# {'n': 324, 'no_trees': 20, 'depth': 2, 'C': 0.2, 'ratio': 2.6, 'sampling_factor': 1.0, 'n_cores': 10, 'wait_time': 100, 'k': 6, 'time_uncached': 3.62396240234375e-05, 'time_cached': 9.298324584960938e-06, 'equality': False, 'mse': 1398.8587243216887, 'true_fourier_norm_squared': 1398.8587243216887, 'computed_fourier_norm_squared': 0, 'measurements': 0}
# {'n': 324, 'no_trees': 20, 'depth': 2, 'C': 0.2, 'ratio': 2.6, 'sampling_factor': 1.1333333333333333, 'n_cores': 10, 'wait_time': 100, 'k': 6, 'time_uncached': 4.2438507080078125e-05, 'time_cached': 1.0013580322265625e-05, 'equality': False, 'mse': 1398.8587243216887, 'true_fourier_norm_squared': 1398.8587243216887, 'computed_fourier_norm_squared': 0, 'measurements': 0}
# {'n': 324, 'no_trees': 20, 'depth': 2, 'C': 0.2, 'ratio': 2.6, 'sampling_factor': 1.2666666666666666, 'n_cores': 10, 'wait_time': 100, 'k': 6, 'time_uncached': 4.220008850097656e-05, 'time_cached': 9.5367431640625e-06, 'equality': False, 'mse': 1398.8587243216887, 'true_fourier_norm_squared': 1398.8587243216887, 'computed_fourier_norm_squared': 0, 'measurements': 0}
# {'n': 324, 'no_trees': 20, 'depth': 2, 'C': 0.2, 'ratio': 2.6, 'sampling_factor': 1.4, 'n_cores': 10, 'wait_time': 100, 'k': 6, 'time_uncached': 2.9325485229492188e-05, 'time_cached': 8.344650268554688e-06, 'equality': False, 'mse': 1398.8587243216887, 'true_fourier_norm_squared': 1398.8587243216887, 'computed_fourier_norm_squared': 0, 'measurements': 0}
# {'n': 324, 'no_trees': 20, 'depth': 2, 'C': 0.2, 'ratio': 5.0, 'sampling_factor': 0.2, 'n_cores': 10, 'wait_time': 100, 'k': 6, 'time_uncached': 3.170967102050781e-05, 'time_cached': 8.106231689453125e-06, 'equality': False, 'mse': 1398.8587243216887, 'true_fourier_norm_squared': 1398.8587243216887, 'computed_fourier_norm_squared': 0, 'measurements': 0}
# {'n': 324, 'no_trees': 20, 'depth': 2, 'C': 0.2, 'ratio': 5.0, 'sampling_factor': 0.33333333333333337, 'n_cores': 10, 'wait_time': 100, 'k': 6, 'time_uncached': 7.462501525878906e-05, 'time_cached': 8.58306884765625e-06, 'equality': False, 'mse': 1398.8587243216887, 'true_fourier_norm_squared': 1398.8587243216887, 'computed_fourier_norm_squared': 0, 'measurements': 0}
# {'n': 324, 'no_trees': 20, 'depth': 2, 'C': 0.2, 'ratio':
 'n_cores': 10, 'wait_time': 100, 'k': 6, 'time_uncached': 3.1213231086730957, 'time_cached': 3.0247209072113037, 'equality': False, 'mse': 22.48169995271104, 'true_fourier_norm_squared': 1398.8587243216887, 'computed_fourier_norm_squared': 1398.8587243216891, 'measurements': 300}
# {'n': 324, 'no_trees': 20, 'depth': 2, 'C': 0.6000000000000001, 'ratio': 1.1, 'sampling_factor': 0.8666666666666667, 'n_cores': 10, 'wait_time': 100, 'k': 6, 'time_uncached': 3.2242720127105713, 'time_cached': 3.2273411750793457, 'equality': False, 'mse': 203.67412819646515, 'true_fourier_norm_squared': 1398.8587243216887, 'computed_fourier_norm_squared': 1441.4913785748663, 'measurements': 348}
# {'n': 324, 'no_trees': 20, 'depth': 2, 'C': 0.6000000000000001, 'ratio': 1.1, 'sampling_factor': 1.0, 'n_cores': 10, 'wait_time': 100, 'k': 6, 'time_uncached': 3.4144625663757324, 'time_cached': 3.3754849433898926, 'equality': False, 'mse': 22.481699952711082, 'true_fourier_norm_squared': 1398.8587243216887, 'computed_fourier_norm_squared': 1625.5797403651427, 'measurements': 408}
# {'n': 324, 'no_trees': 20, 'depth': 2, 'C': 0.6000000000000001, 'ratio': 1.1, 'sampling_factor': 1.1333333333333333, 'n_cores': 10, 'wait_time': 100, 'k': 6, 'time_uncached': 5.108651399612427, 'time_cached': 5.276517391204834, 'equality': False, 'mse': 22.481699952711047, 'true_fourier_norm_squared': 1398.8587243216887, 'computed_fourier_norm_squared': 1489.0082943328184, 'measurements': 456}
# {'n': 324, 'no_trees': 20, 'depth': 2, 'C': 0.6000000000000001, 'ratio': 1.1, 'sampling_factor': 1.2666666666666666, 'n_cores': 10, 'wait_time': 100, 'k': 6, 'time_uncached': 8.423524618148804, 'time_cached': 8.422877550125122, 'equality': False, 'mse': 383.973268218723, 'true_fourier_norm_squared': 1398.8587243216887, 'computed_fourier_norm_squared': 436.2243221968943, 'measurements': 504}
# {'n': 324, 'no_trees': 20, 'depth': 2, 'C': 0.6000000000000001, 'ratio': 1.1, 'sampling_factor': 1.4, 'n_cores': 10, 'wait_time': 100, 'k': 6, 'time_uncached': 3.9112672805786133, 'time_cached': 4.024196147918701, 'equality': False, 'mse': 22.481699952711033, 'true_fourier_norm_squared': 1398.8587243216887, 'computed_fourier_norm_squared': 1489.0082943328182, 'measurements': 564}
# {'n': 324, 'no_trees': 20, 'depth': 2, 'C': 0.6, 'ratio': 2.6, 'sampling_factor': 0.2, 'n_cores': 10, 'wait_time': 100, 'k': 6, 'time_uncached': 9.179115295410156e-05, 'time_cached': 1.0251998901367188e-05, 'equality': False, 'mse': 1398.8587243216887, 'true_fourier_norm_squared': 1398.8587243216887, 'computed_fourier_norm_squared': 0, 'measurements': 0}
# {'n': 324, 'no_trees': 20, 'depth': 2, 'C': 0.6, 'ratio': 2.6, 'sampling_factor': 0.33333333333333337, 'n_cores': 10, 'wait_time': 100, 'k': 6, 'time_uncached': 8.702278137207031e-05, 'time_cached': 1.049041748046875e-05, 'equality': False, 'mse': 1398.8587243216887, 'true_fourier_norm_squared': 1398.8587243216887, 'computed_fourier_norm_squared': 0, 'measurements': 0}
# {'n': 324, 'no_trees': 20, 'depth': 2, 'C': 0.6, 'ratio': 2.6, 'sampling_factor': 0.4666666666666667, 'n_cores': 10, 'wait_time': 100, 'k': 6, 'time_uncached': 7.43865966796875e-05, 'time_cached': 1.0013580322265625e-05, 'equality': False, 'mse': 1398.8587243216887, 'true_fourier_norm_squared': 1398.8587243216887, 'computed_fourier_norm_squared': 0, 'measurements': 0}
# {'n': 324, 'no_trees': 20, 'depth': 2, 'C': 0.6, 'ratio': 2.6, 'sampling_factor': 0.6000000000000001, 'n_cores': 10, 'wait_time': 100, 'k': 6, 'time_uncached': 5.817413330078125e-05, 'time_cached': 9.5367431640625e-06, 'equality': False, 'mse': 1398.8587243216887, 'true_fourier_norm_squared': 1398.8587243216887, 'computed_fourier_norm_squared': 0, 'measurements': 0}
# {'n': 324, 'no_trees': 20, 'depth': 2, 'C': 0.6, 'ratio': 2.6, 'sampling_factor': 0.7333333333333334, 'n_cores': 10, 'wait_time': 100, 'k': 6, 'time_uncached': 7.939338684082031e-05, 'time_cached': 1.049041748046875e-05, 'equality': False, 'mse': 1398.8587243216887, 'true_fourier_norm_squared': 1398.8587243216887, 'computed_fourier_norm_squared': 0, 'measurements': 0}
# {'n': 324, 'no_trees': 20, 'depth': 2, 'C': 0.6, 'ratio': 2.6, 'sampling_factor': 0.8666666666666667, 'n_cores': 10, 'wait_time': 100, 'k': 6, 'time_uncached': 7.939338684082031e-05, 'time_cached': 1.2636184692382812e-05, 'equality': False, 'mse': 1398.8587243216887, 'true_fourier_norm_squared': 1398.8587243216887, 'computed_fourier_norm_squared': 0, 'measurements': 0}
# {'n': 324, 'no_trees': 20, 'depth': 2, 'C': 0.6, 'ratio': 2.6, 'sampling_factor': 1.0, 'n_cores': 10, 'wait_time': 100, 'k': 6, 'time_uncached': 7.05718994140625e-05, 'time_cached': 1.0251998901367188e-05, 'equality': False, 'mse': 1398.8587243216887, 'true_fourier_norm_squared': 1398.8587243216887, 'computed_fourier_norm_squared': 0, 'measurements': 0}
# {'n': 324, 'no_trees': 20, 'depth': 2, 'C': 0.6, 'ratio': 2.6, 'sampling_factor': 1.1333333333333333, 'n_cores': 10, 'wait_time': 100, 'k': 6, 'time_uncached': 8.58306884765625e-05, 'time_cached': 1.0251998901367188e-05, 'equality': False, 'mse': 1398.8587243216887, 'true_fourier_norm_squared': 1398.8587243216887, 'computed_fourier_norm_squared': 0, 'measurements': 0}
# {'n': 324, 'no_trees': 20, 'depth': 2, 'C': 0.6, 'ratio': 2.6, 'sampling_factor': 1.2666666666666666, 'n_cores': 10, 'wait_time': 100, 'k': 6, 'time_uncached': 7.581710815429688e-05, 'time_cached': 1.0251998901367188e-05, 'equality': False, 'mse': 1398.8587243216887, 'true_fourier_norm_squared': 1398.8587243216887, 'computed_fourier_norm_squared': 0, 'measurements': 0}
# {'n': 324, 'no_trees': 20, 'depth': 2, 'C': 0.6, 'ratio': 2.6, 'sampling_factor': 1.4, 'n_cores': 10, 'wait_time': 100, 'k': 6, 'time_uncached': 8.678436279296875e-05, 'time_cached': 9.775161743164062e-06, 'equality': False, 'mse': 1398.8587243216887, 'true_fourier_norm_squared': 1398.8587243216887, 'computed_fourier_norm_squared': 0, 'measurements': 0}
# {'n': 324, 'no_trees': 20, 'depth': 2, 'C': 0.6, 'ratio': 5.0, 'sampling_factor': 0.2, 'n_cores': 10, 'wait_time': 100, 'k': 6, 'time_uncached': 0.00010776519775390625, 'time_cached': 1.049041748046875e-05, 'equality': False, 'mse': 1398.8587243216887, 'true_fourier_norm_squared': 1398.8587243216887, 'computed_fourier_norm_squared': 0, 'measurements': 0}
# {'n': 324, 'no_trees': 20, 'depth': 2, 'C': 0.6, 'ratio': 5.0, 'sampling_factor': 0.33333333333333337, 'n_cores': 10, 'wait_time': 100, 'k': 6, 'time_uncached': 7.939338684082031e-05, 'time_cached': 1.0013580322265625e-05, 'equality': False, 'mse': 1398.8587243216887, 'true_fourier_norm_squared': 1398.8587243216887, 'computed_fourier_norm_squared': 0, 'measurements': 0}
# {'n': 324, 'no_trees': 20, 'depth': 2, 'C': 0.6, 'ratio': 5.0, 'sampling_factor': 0.4666666666666667, 'n_cores': 10, 'wait_time': 100, 'k': 6, 'time_uncached': 8.225440979003906e-05, 'time_cached': 1.0013580322265625e-05, 'equality': False, 'mse': 1398.8587243216887, 'true_fourier_norm_squared': 1398.8587243216887, 'computed_fourier_norm_squared': 0, 'measurements': 0}
# {'n': 324, 'no_trees': 20, 'depth': 2, 'C': 0.6, 'ratio': 5.0, 'sampling_factor': 0.6000000000000001, 'n_cores': 10, 'wait_time': 100, 'k': 6, 'time_uncached': 9.489059448242188e-05, 'time_cached': 1.049041748046875e-05, 'equality': False, 'mse': 1398.8587243216887, 'true_fourier_norm_squared': 1398.8587243216887, 'computed_fourier_norm_squared': 0, 'measurements': 0}
# {'n': 324, 'no_trees': 20, 'depth': 2, 'C': 0.6, 'ratio': 5.0, 'sampling_factor': 0.7333333333333334, 'n_cores': 10, 'wait_time': 100, 'k': 6, 'time_uncached': 6.151199340820312e-05, 'time_cached': 9.5367431640625e-06, 'equality': False, 'mse': 1398.8587243216887, 'true_fourier_norm_squared': 1398.8587243216887, 'computed_fourier_norm_squared': 0, 'measurements': 0}
# {'n': 324, 'no_trees': 20, 'depth': 2, 'C': 0.6, 'ratio': 5.0, 'sampling_factor': 0.8666666666666667, 'n_cores': 10, 'wait_time': 100, 'k': 6, 'time_uncached': 8.368492126464844e-05, 'time_cached': 1.0251998901367188e-05, 'equality': False, 'mse': 1398.8587243216887, 'true_fourier_norm_squared': 1398.8587243216887, 'computed_fourier_norm_squared': 0, 'measurements': 0}
# {'n': 324, 'no_trees': 20, 'depth': 2, 'C': 0.6, 'ratio': 5.0, 'sampling_factor': 1.0, 'n_cores': 10, 'wait_time': 100, 'k': 6, 'time_uncached': 8.535385131835938e-05, 'time_cached': 1.0013580322265625e-05, 'equality': False, 'mse': 1398.8587243216887, 'true_fourier_norm_squared': 1398.8587243216887, 'computed_fourier_norm_squared': 0, 'measurements': 0}
# {'n': 324, 'no_trees': 20, 'depth': 2, 'C': 0.6, 'ratio': 5.0, 'sampling_factor': 1.1333333333333333, 'n_cores': 10, 'wait_time': 100, 'k': 6, 'time_uncached': 8.559226989746094e-05, 'time_cached': 1.0251998901367188e-05, 'equality': False, 'mse': 1398.8587243216887, 'true_fourier_norm_squared': 1398.8587243216887, 'computed_fourier_norm_squared': 0, 'measurements': 0}
# {'n': 324, 'no_trees': 20, 'depth': 2, 'C': 0.6, 'ratio': 5.0, 'sampling_factor': 1.2666666666666666, 'n_cores': 10, 'wait_time': 100, 'k': 6, 'time_uncached': 8.559226989746094e-05, 'time_cached': 1.0013580322265625e-05, 'equality': False, 'mse': 1398.8587243216887, 'true_fourier_norm_squared': 1398.8587243216887, 'computed_fourier_norm_squared': 0, 'measurements': 0}
# {'n': 324, 'no_trees': 20, 'depth': 2, 'C': 0.6, 'ratio': 5.0, 'sampling_factor': 1.4, 'n_cores': 10, 'wait_time': 100, 'k': 6, 'time_uncached': 8.463859558105469e-05, 'time_cached': 1.049041748046875e-05, 'equality': False, 'mse': 1398.8587243216887, 'true_fourier_norm_squared': 1398.8587243216887, 'computed_fourier_norm_squared': 0, 'measurements': 0}
# {'n': 324, 'no_trees': 20, 'depth': 2, 'C': 0.8, 'ratio': 1.1, 'sampling_factor': 0.2, 'n_cores': 10, 'wait_time': 100, 'k': 6, 'time_uncached': 0.5034399032592773, 'time_cached': 0.4596974849700928, 'equality': False, 'mse': 10424.028556716548, 'true_fourier_norm_squared': 1398.8587243216887, 'computed_fourier_norm_squared': 11333.448884552236, 'measurements': 84}
# {'n': 324, 'no_trees': 20, 'depth': 2, 'C': 0.8, 'ratio': 1.1, 'sampling_factor': 0.33333333333333337, 'n_cores': 10, 'wait_time': 100, 'k': 6, 'time_uncached': 0.3440537452697754, 'time_cached': 0.33733463287353516, 'equality': False, 'mse': 383.97326821872343, 'true_fourier_norm_squared': 1398.8587243216887, 'computed_fourier_norm_squared': 2254.485588186162, 'measurements': 144}
# {'n': 324, 'no_trees': 20, 'depth': 2, 'C': 0.8, 'ratio': 1.1, 'sampling_factor': 0.4666666666666667, 'n_cores': 10, 'wait_time': 100, 'k': 6, 'time_uncached': 1.3397400379180908, 'time_cached': 1.2911052703857422, 'equality': False, 'mse': 44.96339990542207, 'true_fourier_norm_squared': 1398.8587243216887, 'computed_fourier_norm_squared': 1511.4899942855293, 'measurements': 192}
# {'n': 324, 'no_trees': 20, 'depth': 2, 'C': 0.8, 'ratio': 1.1, 'sampling_factor': 0.6000000000000001, 'n_cores': 10, 'wait_time': 100, 'k': 6, 'time_uncached': 0.7242355346679688, 'time_cached': 0.6591410636901855, 'equality': False, 'mse': 22.48169995271104, 'true_fourier_norm_squared': 1398.8587243216887, 'computed_fourier_norm_squared': 1452.3624934518502, 'measurements': 240}
# {'n': 324, 'no_trees': 20, 'depth': 2, 'C': 0.8, 'ratio':
 'sampling_factor': 0.2, 'n_cores': 10, 'wait_time': 100, 'k': 2540, 'time_uncached': 108.33133459091187, 'time_cached': 108.51958155632019, 'equality': False, 'mse': 2249.6473448733555, 'true_fourier_norm_squared': 1443.4416470758852, 'computed_fourier_norm_squared': 3442.4858446407566, 'measurements': 11520}
# {'n': 324, 'no_trees': 20, 'depth': 5, 'C': 0.1, 'ratio': 1.1, 'sampling_factor': 0.33333333333333337, 'n_cores': 10, 'wait_time': 100, 'k': 2540, 'time_uncached': 3996.985948562622, 'time_cached': 4018.8132281303406, 'equality': False, 'mse': 691.9843962740866, 'true_fourier_norm_squared': 1443.4416470758852, 'computed_fourier_norm_squared': 1975.214948594929, 'measurements': 18432}
# {'n': 324, 'no_trees': 20, 'depth': 5, 'C': 0.1, 'ratio': 2.6, 'sampling_factor': 0.2, 'n_cores': 10, 'wait_time': 100, 'k': 2540, 'time_uncached': 57.454445362091064, 'time_cached': 57.747506618499756, 'equality': False, 'mse': 2851.785760837078, 'true_fourier_norm_squared': 1443.4416470758852, 'computed_fourier_norm_squared': 4053.0000753986546, 'measurements': 6720}
# {'n': 324, 'no_trees': 20, 'depth': 5, 'C': 0.1, 'ratio': 2.6, 'sampling_factor': 0.33333333333333337, 'n_cores': 10, 'wait_time': 100, 'k': 2540, 'time_uncached': 2350.2727880477905, 'time_cached': 2475.7553629875183, 'equality': False, 'mse': 741.8397277883778, 'true_fourier_norm_squared': 1443.4416470758852, 'computed_fourier_norm_squared': 2024.6295382913304, 'measurements': 10752}
# {'n': 324, 'no_trees': 20, 'depth': 5, 'C': 0.1, 'ratio': 5.0, 'sampling_factor': 0.2, 'n_cores': 10, 'wait_time': 100, 'k': 2540, 'time_uncached': 44.49330520629883, 'time_cached': 44.81215715408325, 'equality': False, 'mse': 1513.2842416675346, 'true_fourier_norm_squared': 1443.4416470758852, 'computed_fourier_norm_squared': 2171.3625679986017, 'measurements': 4800}
# {'n': 324, 'no_trees': 20, 'depth': 5, 'C': 0.1, 'ratio': 5.0, 'sampling_factor': 0.33333333333333337, 'n_cores': 10, 'wait_time': 100, 'k': 2540, 'time_uncached': 1768.0125751495361, 'time_cached': 1765.0603194236755, 'equality': False, 'mse': 372.3883035329996, 'true_fourier_norm_squared': 1443.4416470758852, 'computed_fourier_norm_squared': 1648.2840441939666, 'measurements': 7680}
# {'n': 324, 'no_trees': 20, 'depth': 5, 'C': 0.15, 'ratio': 1.1, 'sampling_factor': 0.2, 'n_cores': 10, 'wait_time': 100, 'k': 2540, 'time_uncached': 218.48482203483582, 'time_cached': 214.80308866500854, 'equality': False, 'mse': 1087.8625378684012, 'true_fourier_norm_squared': 1443.4416470758852, 'computed_fourier_norm_squared': 2275.7850497793547, 'measurements': 23040}
# {'n': 324, 'no_trees': 20, 'depth': 5, 'C': 0.15, 'ratio': 1.1, 'sampling_factor': 0.33333333333333337, 'n_cores': 10, 'wait_time': 100, 'k': 2540, 'time_uncached': 7550.450924396515, 'time_cached': 8005.69135093689, 'equality': False, 'mse': 706.0327114714617, 'true_fourier_norm_squared': 1443.4416470758852, 'computed_fourier_norm_squared': 1981.8936114391772, 'measurements': 36864}
# {'n': 324, 'no_trees': 20, 'depth': 5, 'C': 0.15, 'ratio': 2.6, 'sampling_factor': 0.2, 'n_cores': 10, 'wait_time': 100, 'k': 2540, 'time_uncached': 107.46848344802856, 'time_cached': 107.90186905860901, 'equality': False, 'mse': 1059.7781566215647, 'true_fourier_norm_squared': 1443.4416470758852, 'computed_fourier_norm_squared': 2210.8785471884134, 'measurements': 12480}
# {'n': 324, 'no_trees': 20, 'depth': 5, 'C': 0.15, 'ratio': 2.6, 'sampling_factor': 0.33333333333333337, 'n_cores': 10, 'wait_time': 100, 'k': 2540, 'time_uncached': 3659.251945734024, 'time_cached': 3676.1158740520477, 'equality': False, 'mse': 693.5158000131266, 'true_fourier_norm_squared': 1443.4416470758852, 'computed_fourier_norm_squared': 1956.5884431666148, 'measurements': 19968}
# {'n': 324, 'no_trees': 20, 'depth': 5, 'C': 0.15, 'ratio': 5.0, 'sampling_factor': 0.2, 'n_cores': 10, 'wait_time': 100, 'k': 2540, 'time_uncached': 95.62969207763672, 'time_cached': 94.52192425727844, 'equality': False, 'mse': 614.6400058263724, 'true_fourier_norm_squared': 1443.4416470758852, 'computed_fourier_norm_squared': 1761.6591718992233, 'measurements': 9600}
# {'n': 324, 'no_trees': 20, 'depth': 5, 'C': 0.15, 'ratio': 5.0, 'sampling_factor': 0.33333333333333337, 'n_cores': 10, 'wait_time': 100, 'k': 2540, 'time_uncached': 3083.616930961609, 'time_cached': 3033.8977568149567, 'equality': False, 'mse': 402.0598756072145, 'true_fourier_norm_squared': 1443.4416470758852, 'computed_fourier_norm_squared': 1663.2943043799398, 'measurements': 15360}
# {'n': 324, 'no_trees': 20, 'depth': 5, 'C': 0.2, 'ratio': 1.1, 'sampling_factor': 0.2, 'n_cores': 10, 'wait_time': 100, 'k': 2540, 'time_uncached': 205.84892964363098, 'time_cached': 205.62871980667114, 'equality': False, 'mse': 1087.8625378684012, 'true_fourier_norm_squared': 1443.4416470758852, 'computed_fourier_norm_squared': 2275.7850497793547, 'measurements': 23040}
# {'n': 324, 'no_trees': 20, 'depth': 5, 'C': 0.2, 'ratio': 1.1, 'sampling_factor': 0.33333333333333337, 'n_cores': 10, 'wait_time': 100, 'k': 2540, 'time_uncached': 6859.456622600555, 'time_cached': 7488.778635978699, 'equality': False, 'mse': 706.0327114714617, 'true_fourier_norm_squared': 1443.4416470758852, 'computed_fourier_norm_squared': 1981.8936114391772, 'measurements': 36864}
# {'n': 324, 'no_trees': 20, 'depth': 5, 'C': 0.2, 'ratio': 2.6, 'sampling_factor': 0.2, 'n_cores': 10, 'wait_time': 100, 'k': 2540, 'time_uncached': 119.12440848350525, 'time_cached': 119.22191619873047, 'equality': False, 'mse': 1125.454705013748, 'true_fourier_norm_squared': 1443.4416470758852, 'computed_fourier_norm_squared': 2278.2200547163025, 'measurements': 13440}
# {'n': 324, 'no_trees': 20, 'depth': 5, 'C': 0.2, 'ratio': 2.6, 'sampling_factor': 0.33333333333333337, 'n_cores': 10, 'wait_time': 100, 'k': 2540, 'time_uncached': 4213.251132011414, 'time_cached': 4231.566665172577, 'equality': False, 'mse': 708.3911726241448, 'true_fourier_norm_squared': 1443.4416470758852, 'computed_fourier_norm_squared': 1968.0599031403958, 'measurements': 21504}
# {'n': 324, 'no_trees': 20, 'depth': 5, 'C': 0.2, 'ratio': 5.0, 'sampling_factor': 0.2, 'n_cores': 10, 'wait_time': 100, 'k': 2540, 'time_uncached': 83.82314968109131, 'time_cached': 84.21081233024597, 'equality': False, 'mse': 614.6400058263724, 'true_fourier_norm_squared': 1443.4416470758852, 'computed_fourier_norm_squared': 1761.6591718992233, 'measurements': 9600}
# {'n': 324, 'no_trees': 20, 'depth': 5, 'C': 0.2, 'ratio': 5.0, 'sampling_factor': 0.33333333333333337, 'n_cores': 10, 'wait_time': 100, 'k': 2540, 'time_uncached': 2706.0141203403473, 'time_cached': 2742.5402612686157, 'equality': False, 'mse': 402.0598756072145, 'true_fourier_norm_squared': 1443.4416470758852, 'computed_fourier_norm_squared': 1663.2943043799398, 'measurements': 15360}
# {'n': 324, 'no_trees': 20, 'depth': 5, 'C': 0.4, 'ratio': 1.1, 'sampling_factor': 0.2, 'n_cores': 10, 'wait_time': 100, 'k': 2540, 'time_uncached': 359.00876355171204, 'time_cached': 359.3343138694763, 'equality': False, 'mse': 1011.3702730110713, 'true_fourier_norm_squared': 1443.4416470758852, 'computed_fourier_norm_squared': 2181.595775792779, 'measurements': 46080}
# {'n': 324, 'no_trees': 20, 'depth': 5, 'C': 0.4, 'ratio': 1.1, 'sampling_factor': 0.33333333333333337, 'n_cores': 10, 'wait_time': 100, 'k': 2540, 'time_uncached': 12797.8982796669, 'time_cached': 13224.346884965897, 'equality': False, 'mse': 667.1880129916316, 'true_fourier_norm_squared': 1443.4416470758852, 'computed_fourier_norm_squared': 1969.0383438669628, 'measurements': 73728}
# {'n': 324, 'no_trees': 20, 'depth': 5, 'C': 0.4, 'ratio': 2.6, 'sampling_factor': 0.2, 'n_cores': 10, 'wait_time': 100, 'k': 2540, 'time_uncached': 214.474187374115, 'time_cached': 218.29946184158325, 'equality': False, 'mse': 1014.256432247908, 'true_fourier_norm_squared': 1443.4416470758852, 'computed_fourier_norm_squared': 2175.5835645877073, 'measurements': 26880}
# {'n': 324, 'no_trees': 20, 'depth': 5, 'C': 0.4, 'ratio': 2.6, 'sampling_factor': 0.33333333333333337, 'n_cores': 10, 'wait_time': 100, 'k': 2540, 'time_uncached': 7555.838752508163, 'time_cached': 7538.940964221954, 'equality': False, 'mse': 706.3422389855574, 'true_fourier_norm_squared': 1443.4416470758852, 'computed_fourier_norm_squared': 2008.433037535737, 'measurements': 43008}
# {'n': 324, 'no_trees': 20, 'depth': 5, 'C': 0.4, 'ratio': 5.0, 'sampling_factor': 0.2, 'n_cores': 10, 'wait_time': 100, 'k': 2540, 'time_uncached': 159.79505705833435, 'time_cached': 158.59829783439636, 'equality': False, 'mse': 1159.5208143833001, 'true_fourier_norm_squared': 1443.4416470758852, 'computed_fourier_norm_squared': 2317.550651718806, 'measurements': 20160}
# {'n': 324, 'no_trees': 20, 'depth': 5, 'C': 0.4, 'ratio': 5.0, 'sampling_factor': 0.33333333333333337, 'n_cores': 10, 'wait_time': 100, 'k': 2540, 'time_uncached': 5667.322623968124, 'time_cached': 5762.215073823929, 'equality': False, 'mse': 842.322686145235, 'true_fourier_norm_squared': 1443.4416470758852, 'computed_fourier_norm_squared': 2115.560747591587, 'measurements': 32256}
# {'n': 324, 'no_trees': 20, 'depth': 5, 'C': 0.6000000000000001, 'ratio': 1.1, 'sampling_factor': 0.2, 'n_cores': 10, 'wait_time': 100, 'k': 2540, 'time_uncached': 755.3776361942291, 'time_cached': 766.4011914730072, 'equality': False, 'mse': 1036.1546145865398, 'true_fourier_norm_squared': 1443.4416470758852, 'computed_fourier_norm_squared': 2237.680710450391, 'measurements': 92160}
# {'n': 324, 'no_trees': 20, 'depth': 5, 'C': 0.8, 'ratio': 1.1, 'sampling_factor': 0.2, 'n_cores': 10, 'wait_time': 100, 'k': 2540, 'time_uncached': 678.3223013877869, 'time_cached': 679.896205663681, 'equality': False, 'mse': 1036.1546145865398, 'true_fourier_norm_squared': 1443.4416470758852, 'computed_fourier_norm_squared': 2237.680710450391, 'measurements': 92160}

# %%
plt.rc('font', size=18)          # controls default text sizes
plt.rc('legend', fontsize=15)
d_to_m = {2:600, 3:6000, 4:15000, 5:40000, 6:1000000}
for depth in [2, 3, 4, 5, 6]:
    fig, ax = plt.subplots()
    ax.set_ylabel("mse (%)")
    ax.set_xlabel("number of measurements")
    ax.plot([a[0] for a in result_binning[depth] if a[0]<d_to_m[depth]],[a[1] for a in result_binning[depth] if a[0]<d_to_m[depth]],'x',  color ='#FFA500', markersize =2, label="binning" )
    ax.plot([a[0] for a in result_reed_solomon[depth] if a[0]<d_to_m[depth]],[a[1] for a in result_reed_solomon[depth] if a[0]<d_to_m[depth]],'*', markersize=15, color='g', label="reed_solomon")
    if depth <= 5:
        ax.plot([a[0] for a in result_random[depth] if a[0]<d_to_m[depth] ],[a[1] for a in result_random[depth] if a[0]<d_to_m[depth]],'.', color='b', label="random")
    ax.xaxis.grid()
    ax.yaxis.grid()
    ax.set_title(f"degree={depth}")
    plt.legend()
    plt.savefig(f"plots/superconduct-n={n}_d={depth}", dpi=300,  bbox_inches='tight')
    plt.show()

# %%
for depth in [2,3,4,5]:
    fig, ax = plt.subplots()
    ax.set_ylabel("mse", color="blue")
    ax.set_xlabel("number of measurments")
    ax.plot([a[0] for a in result_binning[depth] if a[0]<2500],[a[1] for a in result_binning[depth] if a[0]<2500],'b.')
    ax.plot([a[0] for a in result_random[depth] if a[0]<2500 ],[a[1] for a in result_random[depth] if a[0]<2500],'r*', markersize=4)
    # ax.plot([a[0] for a in result_reed_solomon[depth]],[a[1] for a in result_reed_solomon[depth]],'g*', markersize=4)
    ax.xaxis.grid()
    ax.yaxis.grid()
    ax.set_title(f"degree={depth}")
    #plt.savefig(f"images/random/n={n}_d={degree}", dpi=300)
    plt.show()
