# %%
import numpy as np
import matplotlib.pyplot as plt
import json
import math

# %%
dataset = "superconduct"
n = 20 
no_trees = 100

# %%
# Proximal method
result_cs = {}
for depth in range(2,5):
    result_cs[depth] = []
    for C in np.linspace(0.8,1.6,10):
        for lmda_i, lmda in enumerate(10 ** np.linspace(-4,1,8)):
            try:
                f =open(f"../results/cs/{dataset}_n={n}_no_trees={no_trees}_depth={depth}_C={C:.3}_lambda={lmda:.6}.json")
                data = json.loads(f.read())
                result_cs[depth].append((data["measurements"], data["mse"]/data['true_fourier_norm_squared']))
            except:
                print(f"Couldn't find results/{dataset}_n={n}_no_trees={no_trees}_depth={depth}C={C:.3}_lambda={lmda:.6}.json")
# Out:
# Couldn't find results/superconduct_n=20_no_trees=100_depth=4C=1.24_lambda=0.372759.json
# Couldn't find results/superconduct_n=20_no_trees=100_depth=4C=1.24_lambda=1.9307.json
# Couldn't find results/superconduct_n=20_no_trees=100_depth=4C=1.33_lambda=0.0001.json
# Couldn't find results/superconduct_n=20_no_trees=100_depth=4C=1.33_lambda=0.0026827.json
# Couldn't find results/superconduct_n=20_no_trees=100_depth=4C=1.33_lambda=0.013895.json
# Couldn't find results/superconduct_n=20_no_trees=100_depth=4C=1.33_lambda=0.0719686.json
# Couldn't find results/superconduct_n=20_no_trees=100_depth=4C=1.33_lambda=0.372759.json
# Couldn't find results/superconduct_n=20_no_trees=100_depth=4C=1.33_lambda=10.0.json
# Couldn't find results/superconduct_n=20_no_trees=100_depth=4C=1.42_lambda=0.0001.json
# Couldn't find results/superconduct_n=20_no_trees=100_depth=4C=1.42_lambda=0.000517947.json
# Couldn't find results/superconduct_n=20_no_trees=100_depth=4C=1.42_lambda=0.0026827.json
# Couldn't find results/superconduct_n=20_no_trees=100_depth=4C=1.42_lambda=0.013895.json
# Couldn't find results/superconduct_n=20_no_trees=100_depth=4C=1.42_lambda=0.0719686.json
# Couldn't find results/superconduct_n=20_no_trees=100_depth=4C=1.42_lambda=0.372759.json
# Couldn't find results/superconduct_n=20_no_trees=100_depth=4C=1.42_lambda=1.9307.json
# Couldn't find results/superconduct_n=20_no_trees=100_depth=4C=1.42_lambda=10.0.json
# Couldn't find results/superconduct_n=20_no_trees=100_depth=4C=1.51_lambda=0.0001.json
# Couldn't find results/superconduct_n=20_no_trees=100_depth=4C=1.51_lambda=0.000517947.json
# Couldn't find results/superconduct_n=20_no_trees=100_depth=4C=1.51_lambda=0.0026827.json
# Couldn't find results/superconduct_n=20_no_trees=100_depth=4C=1.51_lambda=0.013895.json
# Couldn't find results/superconduct_n=20_no_trees=100_depth=4C=1.51_lambda=0.0719686.json
# Couldn't find results/superconduct_n=20_no_trees=100_depth=4C=1.51_lambda=0.372759.json
# Couldn't find results/superconduct_n=20_no_trees=100_depth=4C=1.51_lambda=1.9307.json
# Couldn't find results/superconduct_n=20_no_trees=100_depth=4C=1.51_lambda=10.0.json
# Couldn't find results/superconduct_n=20_no_trees=100_depth=4C=1.6_lambda=0.0001.json
# Couldn't find results/superconduct_n=20_no_trees=100_depth=4C=1.6_lambda=0.000517947.json
# Couldn't find results/superconduct_n=20_no_trees=100_depth=4C=1.6_lambda=0.0026827.json
# Couldn't find results/superconduct_n=20_no_trees=100_depth=4C=1.6_lambda=0.013895.json
# Couldn't find results/superconduct_n=20_no_trees=100_depth=4C=1.6_lambda=0.0719686.json
# Couldn't find results/superconduct_n=20_no_trees=100_depth=4C=1.6_lambda=0.372759.json
# Couldn't find results/superconduct_n=20_no_trees=100_depth=4C=1.6_lambda=1.9307.json
# Couldn't find results/superconduct_n=20_no_trees=100_depth=4C=1.6_lambda=10.0.json

# %%
print(result_cs)
# Out:
# {2: [(55, 0.5106469665456052), (55, 0.2422278947961466), (55, 1.9875336365949996e-08), (55, 5.331901001908436e-07), (55, 1.4303489479452711e-05), (55, 0.00036616283252144816), (55, 0.004936419684716552), (55, 0.12426212396598772), (61, 0.47991768029328247), (61, 0.07693521272744529), (61, 1.967824692360942e-08), (61, 5.278648095842148e-07), (61, 1.4162325150062554e-05), (61, 0.00035996612864095203), (61, 0.004484888841134679), (61, 0.1103849089041539), (67, 0.41649414414918323), (67, 0.03053673847026319), (67, 1.9065754421556795e-08), (67, 5.115192010517231e-07), (67, 1.3721211798992391e-05), (67, 0.0003485165355124326), (67, 0.0043629473646450145), (67, 0.1062263713743633), (73, 0.4145496729234271), (73, 0.0008502775164230754), (73, 1.6346353666728984e-08), (73, 4.3853297752296174e-07), (73, 1.1763862319297152e-05), (73, 0.00031560737816239417), (73, 0.004239603528690443), (73, 0.10208722811457249), (79, 0.26734759252518886), (79, 6.459188842987451e-10), (79, 1.7328508206143998e-08), (79, 4.6487317728335755e-07), (79, 1.2471419711792242e-05), (79, 0.000334563701494126), (79, 0.004243510988951591), (79, 0.10057032655720245), (86, 0.23691037853826688), (86, 0